# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
import seaborn as sns

# %%
data = pd.read_csv("../../framingham_heart_study.csv")

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
data.shape
# Out:
# (4240, 16)

# %%
data.isnull().values.any(), data.isnull().values.sum()
# Out:
# (True, 645)

# %%
# imputation of missing values
new_data = data.fillna(method="bfill", axis=0) # axis=0 means you replace with the value in the row

# %%
new_data.isnull().values.any(), new_data.isnull().values.sum()
# Out:
# (False, 0)

# %%
new_data.shape
# Out:
# (4240, 16)

# %%
new_data['TenYearCHD'].value_counts() # clear indication of an imbalanced dataset
# Out:
# 0    3596
# 1     644
# Name: TenYearCHD, dtype: int64

# %%
sns.countplot(x='TenYearCHD', data=new_data, palette='Blues')

# %%
# Correlation Matrix Heatmap
f, ax = plt.subplots(figsize=(16, 10))
corr = new_data.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="Blues",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Heart disease feature correlation heatmap', fontsize=14)

# %%
# before balancing the data set and before PCA

# %%
X_before_balancing = new_data.drop(['TenYearCHD'], axis=1)
y_before_balancing = new_data['TenYearCHD']

# %%
X_before_balancing
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose
# 0          80.0     77.0
# 1          95.0     76.0
# 2          75.0     70.0
# 3          65.0    103.0
# 4          85.0     85.0
# ...         ...      ...
# 4235       84.0     86.0
# 4236       86.0    107.0
# 4237       80.0    107.0
# 4238       67.0     72.0
# 4239       85.0     80.0
#
# [4240 rows x 15 columns]

# %%
y_before_balancing
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4235    0
# 4236    0
# 4237    0
# 4238    0
# 4239    0
# Name: TenYearCHD, Length: 4240, dtype: int64

# %%
X_train_before_balancing, X_test_before_balancing, y_train_before_balancing, y_test_before_balancing = train_test_split(X_before_balancing, y_before_balancing, test_size=0.3, random_state=100)

# %%
# nb classifier
nb_classifier_before_balancing = GaussianNB()

# %%
# fitting the classifier
nb_classifier_before_balancing.fit(X_train_before_balancing, y_train_before_balancing)
# Out:
# GaussianNB()

# %%
# predicting y
y_pred_before_balancing = nb_classifier_before_balancing.predict(X_test_before_balancing)

# %%
# prediction accuracy before data balancing
print(metrics.accuracy_score(y_test_before_balancing, y_pred_before_balancing))
# Out:
# 0.8404088050314465

# %%
# classification report
print(classification_report(y_test_before_balancing, y_pred_before_balancing))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1094
#            1       0.38      0.21      0.27       178
#
#     accuracy                           0.84      1272
#    macro avg       0.63      0.58      0.59      1272
# weighted avg       0.81      0.84      0.82      1272

# %%
# confusion matrix
print(plot_confusion_matrix(nb_classifier_before_balancing, X_test_before_balancing, y_test_before_balancing, cmap="Greys"))
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000002614483A760>

# %%
# with and without PCA before and after oversampling

# %%
# standard scaling to ensure that in every feature, the mean=0 and std deviation=1
scaler = StandardScaler()
scaler.fit(new_data)
# Out:
# StandardScaler()

# %%
scaled_new_data = scaler.transform(new_data)

# %%
# PCA for dimension reduction
from sklearn.decomposition import PCA

# %%
# n_components=2 means we convert number of features to 2
# If 0 < n_components < 1 and svd_solver == 'full', select the number of components 
# such that the amount of variance that needs to be explained is greater than the percentage specified by n_components.
# pca = PCA(n_components=6, svd_solver='full')
pca = PCA(n_components=8)

# %%
pca.fit(scaled_new_data)
# Out:
# PCA(n_components=12)

# %%
x_pca = pca.transform(scaled_new_data) # this is the independent features

# %%
print(x_pca)
# Out:
# [[-1.88330615 -1.00877129  0.04138475 ...  1.1768886   1.01063005
#   -0.16546024]
#  [-0.12966797 -1.34340652 -0.22539497 ...  1.15558739  0.31227138
#   -0.20072773]
#  [-1.02683895  1.40370557 -0.21170218 ... -0.13001273  0.46846019
#    0.26882078]
#  ...
#  [ 0.04367643 -1.53194827  0.62610214 ... -0.51064134  0.38465249
#    0.50956454]
#  [ 0.66719924 -0.30216686 -1.00979071 ... -0.6149896   0.27120818
#    0.95162069]
#  [-1.62088732  1.4547887  -0.16497419 ... -0.55315791 -0.46336277
#   -0.06344964]]

# %%
# shape of scaled data before dimension reduction
scaled_new_data.shape
# Out:
# (4240, 16)

# %%
# shape of scaled data before dimension reduction
x_pca.shape
# Out:
# (4240, 12)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0], x_pca[:,1], c=new_data["TenYearCHD"], cmap="plasma")
plt.xlabel("First principal component")
plt.ylabel("Second principal component")
plt.colorbar()

# %%
# new reduced dimensions vs initial data before dimension reduction
X_new = pca.inverse_transform(x_pca)
plt.scatter(x_pca[:, 0], x_pca[:, 1], alpha=0.2)
plt.scatter(X_new[:, 0], X_new[:, 2], alpha=0.8)
plt.axis('equal');

# %%
# Naive Bayes

# %%
X = x_pca
y = new_data["TenYearCHD"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
# nb classifier
nb_classifier = GaussianNB()

# %%
# fitting the classifier
nb_classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# predicting y
y_pred = nb_classifier.predict(X_test)

# %%
# prediction accuracy
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9709119496855346

# %%
# classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      1094
#            1       0.83      1.00      0.91       178
#
#     accuracy                           0.97      1272
#    macro avg       0.91      0.98      0.94      1272
# weighted avg       0.98      0.97      0.97      1272

# %%
# confusion matrix
print(plot_confusion_matrix(nb_classifier, X_test, y_test, cmap="Greys"))
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000002614638FB20>

# %%
# checking which number of dimensions gives higher accuracy

# %%
# finding the best number of components after oversampling with SMOTE
for component in range(1,16):
    pca = PCA(n_components=component)
    pca.fit(scaled_new_data)
    x_pca = pca.transform(scaled_new_data)
    X = x_pca
    y = new_data["TenYearCHD"]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)
    nb_classifier = GaussianNB().fit(X_train, y_train)
    y_pred = nb_classifier.predict(X_test)
    
    accuracy = metrics.accuracy_score(y_test, y_pred)
    print("Component:",component)
    print("Accuracy:",accuracy*100)
    print("******************************")
# Out:
# Component: 1
# Accuracy: 85.77044025157232
# ******************************
# Component: 2
# Accuracy: 86.0062893081761
# ******************************
# Component: 3
# Accuracy: 86.08490566037736
# ******************************
# Component: 4
# Accuracy: 87.89308176100629
# ******************************
# Component: 5
# Accuracy: 88.12893081761007
# ******************************
# Component: 6
# Accuracy: 86.79245283018868
# ******************************
# Component: 7
# Accuracy: 87.65723270440252
# ******************************
# Component: 8
# Accuracy: 95.59748427672956
# ******************************
# Component: 9
# Accuracy: 93.55345911949685
# ******************************
# Component: 10
# Accuracy: 96.14779874213836
# ******************************
# Component: 11
# Accuracy: 96.77672955974843
# ******************************
# Component: 12
# Accuracy: 97.09119496855347
# ******************************
# Component: 13
# Accuracy: 96.4622641509434
# ******************************
# Component: 14
# Accuracy: 96.4622641509434
# ******************************
# Component: 15
# Accuracy: 96.4622641509434
# ******************************

# %%
# After oversampling and PCA
# oversampling with SMOTE
from imblearn.over_sampling import SMOTE, ADASYN

# %%
sm = SMOTE(random_state=100)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())

# %%
print("After oversampling, shape of train x: ", X_train_res.shape)
print("After oversampling, shape of train y: ", y_train_res.shape)
# Out:
# After oversampling, shape of train x:  (5004, 15)
# After oversampling, shape of train y:  (5004,)

# %%
# svm after oversampling
nb_classifier.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %%
y_pred2 = nb_classifier.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred2))
# classification report
print(classification_report(y_test, y_pred2))
# Out:
# Accuracy: 0.9638364779874213
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      1094
#            1       0.80      0.99      0.89       178
#
#     accuracy                           0.96      1272
#    macro avg       0.90      0.98      0.93      1272
# weighted avg       0.97      0.96      0.97      1272

# %%
print(plot_confusion_matrix(nb_classifier, X_test, y_test, cmap="Greys"))
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000026144957AC0>

# %%
# finding the best number of components after oversampling with SMOTE
for component in range(1,16):
    pca = PCA(n_components=component)
    pca.fit(scaled_new_data)
    x_pca = pca.transform(scaled_new_data)
    X = x_pca
    y = new_data["TenYearCHD"]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)
    sm = SMOTE(random_state=100)
    X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())
    nb_classifier = GaussianNB().fit(X_train_res, y_train_res)
    y_pred3 = nb_classifier.predict(X_test)
    
    accuracy = metrics.accuracy_score(y_test, y_pred3)
    print("Components:",component)
    print("Accuracy:",accuracy*100)
    print("******************************")
# Out:
# Components: 1
# Accuracy: 70.9119496855346
# ******************************
# Components: 2
# Accuracy: 72.16981132075472
# ******************************
# Components: 3
# Accuracy: 79.16666666666666
# ******************************
# Components: 4
# Accuracy: 88.52201257861635
# ******************************
# Components: 5
# Accuracy: 91.5880503144654
# ******************************
# Components: 6
# Accuracy: 90.25157232704403
# ******************************
# Components: 7
# Accuracy: 90.09433962264151
# ******************************
# Components: 8
# Accuracy: 97.562893081761
# ******************************
# Components: 9
# Accuracy: 96.69811320754717
# ******************************
# Components: 10
# Accuracy: 97.0125786163522
# ******************************
# Components: 11
# Accuracy: 97.0125786163522
# ******************************
# Components: 12
# Accuracy: 97.09119496855347
# ******************************
# Components: 13
# Accuracy: 96.4622641509434
# ******************************
# Components: 14
# Accuracy: 96.4622641509434
# ******************************
# Components: 15
# Accuracy: 96.38364779874213
# ******************************

# %%
# graph showing accuracy per number of components

# %%
# after oversampling, before PCA

# %%
x_before_pca = new_data.drop(['TenYearCHD'], axis=1)
y_before_pca = new_data['TenYearCHD']

# %%
X_train_no_pca, X_test_no_pca, y_train_no_pca, y_test_no_pca = train_test_split(x_before_pca, y_before_pca, test_size=0.3, random_state=100)

# %%
# oversampling with SMOTE
sm_no_pca = SMOTE(random_state=100)
X_train_res_no_pca, y_train_res_no_pca = sm_no_pca.fit_sample(X_train_no_pca, y_train_no_pca.ravel())

# %%
print("After oversampling, shape of train x: ", X_train_res_no_pca.shape)
print("After oversampling, shape of train y: ", y_train_res_no_pca.shape)
# Out:
# After oversampling, shape of train x:  (5004, 15)
# After oversampling, shape of train y:  (5004,)

# %%
# NB classifier after oversampling before PCA
nb_classifier.fit(X_train_res_no_pca, y_train_res_no_pca)
# Out:
# GaussianNB()

# %%
y_pred_no_pca = nb_classifier.predict(X_test_no_pca)

# %%
print(metrics.accuracy_score(y_test_no_pca, y_pred_no_pca)*100)
print(classification_report(y_test_no_pca, y_pred_no_pca))
# Out:
# 75.31446540880503
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      1094
#            1       0.25      0.37      0.30       178
#
#     accuracy                           0.75      1272
#    macro avg       0.57      0.59      0.57      1272
# weighted avg       0.80      0.75      0.77      1272

# %%
print(plot_confusion_matrix(nb_classifier, X_test_no_pca, y_test_no_pca, cmap="Greys"))
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000026143DB8130>
